# %% [markdown]
# ## Creation of figures of flux vs TS, for all cases (different $\sigma$'s, different b's, different dark matter masses)
#
# ## Comparison NFW - 1PS

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from code.plot_utils import plot_pretty
# %matplotlib inline

# %% [markdown]
# First thing we have to do is to create arrays for all cases we consider here

# %% [markdown]
# #### Flux is everytime the same, let's create an array here

# %%
flux = np.array([4.0e-9,2.67e-9,1.33e-9,3.3e-10])

# %% [markdown]
# ##### DM = 10GeV

# %%
#===================================================
#===================================================
# First everything with σ = 0.05
#===================================================
#===================================================

#--------------------------------------------------
# Fermi only
#--------------------------------------------------

DM_10_sig_005_b_20_Ferm = np.array([0.615,0.335,0.0399,0.0189])
DM_10_sig_005_b_20_Ferm_error = np.array([0.02775127625,0.02044830881,0.03573798166,0.0105077749])

DM_10_sig_005_b_40_Ferm = np.array([0.67,0.418,0.0806,0.02])
DM_10_sig_005_b_40_Ferm_error = np.array([0.03085503741,0.0219089023,0.02188296141,0.006261309767])

DM_10_sig_005_b_60_Ferm = np.array([0.756,0.4,0.147,0.0307])
DM_10_sig_005_b_60_Ferm_error = np.array([0.03122018578,0.02391721834,0.04174242446,0.01258623587])

#--------------------------------------------------
# Fermi + ASTROGAM
#--------------------------------------------------

# FA means Fermi + ASTROGAM

DM_10_sig_005_b_20_FA = np.array([7.67,4.63,1.97,0.233])   
DM_10_sig_005_b_20_FA_error = np.array([0.1004158022,0.077228880610,0.165122177,0.06293117934])

DM_10_sig_005_b_40_FA = np.array([8.08,4.96,2.27,0.298])
DM_10_sig_005_b_40_FA_error = np.array([0.1062581762,0.08234095781,0.09202227991,0.03573373756])

DM_10_sig_005_b_60_FA = np.array([8.53,5.15,2.19,0.543])
DM_10_sig_005_b_60_FA_error = np.array([0.1113702534,0.08325382874,0.1680089283,0.06235382907])

#==================================================
#==================================================
# Eveything with σ = 0.10 
#==================================================
#==================================================

#--------------------------------------------------
# Fermi only
#--------------------------------------------------



DM_10_sig_010_b_20_Ferm = np.array([1.24,0.682,0.164,0.0346])
DM_10_sig_010_b_20_Ferm_error = np.array([0.135099963,0.09468544415,0.05421319028,0.01605033748])

DM_10_sig_010_b_40_Ferm = np.array([1.4,0.669,0.295,0.0359])
DM_10_sig_010_b_40_Ferm_error = np.array([0.1356773133,0.105077749,0.03288768767,0.009992797406])

DM_10_sig_010_b_60_Ferm = np.array([1.49,0.771,0.244,0.00839])
DM_10_sig_010_b_60_Ferm_error = np.array([0.1478016689,0.1033456982,0.06235382907,0.01991858429])


#--------------------------------------------------
# Fermi + ASTROGAM
#--------------------------------------------------


# FA means Fermi + ASTROGAM

DM_10_sig_010_b_20_FA = np.array([42.6,24.3,10.4,1.6])   
DM_10_sig_010_b_20_FA_error = np.array([0.7967433715,0.6062177826,0.3666174209,0.1472243186])

DM_10_sig_010_b_40_FA = np.array([45.5,28.0,11.4,1.91])
DM_10_sig_010_b_40_FA_error = np.array([0.8140638796,0.5888972746,0.2150348809,0.08696263565])

DM_10_sig_010_b_60_FA = np.array([47.5,27.8,12.1,1.88])
DM_10_sig_010_b_60_FA_error = np.array([0.8082903769,0.675499815,0.4324353516,0.1622354256])



#==================================================
#==================================================
# Everything with σ = 0.25
#==================================================
#==================================================


#--------------------------------------------------
# Fermi only
#--------------------------------------------------

DM_10_sig_025_b_20_Ferm = np.array([17.8,9.94,3.43,0.368])
DM_10_sig_025_b_20_Ferm_error = np.array([0.4688084186,0.3654627204,0.2049593456,0.06119912853])

DM_10_sig_025_b_40_Ferm = np.array([19.9,11.4,4.01,0.433])
DM_10_sig_025_b_40_Ferm_error = np.array([0.5334716487,0.375277675,0.1274397897,0.03921224299])

DM_10_sig_025_b_60_Ferm = np.array([22.2,12.8,4.48,0.497])
DM_10_sig_025_b_60_Ferm_error = np.array([0.5444413038,0.3931755333,0.2384456612,0.07967433715])


#--------------------------------------------------
# Fermi + ASTROGAM
#--------------------------------------------------

DM_10_sig_025_b_20_FA = np.array([397,227,88.1,13.2])
DM_10_sig_025_b_20_FA_error = np.array([2.326721585,1.986084926,1.05077749,0.3787417766])

DM_10_sig_025_b_40_FA = np.array([442.0,255.0,100.0,14.5])
DM_10_sig_025_b_40_FA_error = np.array([2.782828297,1.905255888,0.6577537533,0.2336923191])

DM_10_sig_025_b_60_FA = np.array([475.0,278.0,108.0,15.6])
DM_10_sig_025_b_60_FA_error = np.array([2.863657335,2.090007974,1.131606528,0.4843968759])

# %% [markdown]
# ##### DM = 30 GeV

# %%
#===================================================
#===================================================
# First everything with σ = 0.05
#===================================================
#===================================================

#--------------------------------------------------
# Fermi only
#--------------------------------------------------

DM_30_sig_005_b_20_Ferm = np.array([1.82,1.04,0.464,0.0146])
DM_30_sig_005_b_20_Ferm_error = np.array([0.04874730762,0.03633226298,0.07043673284,0.02355589098])

DM_30_sig_005_b_40_Ferm = np.array([1.92,1.12,0.439,0.0575])
DM_30_sig_005_b_40_Ferm_error = np.array([0.05057304948,0.03888830158,0.04300697618,0.01476783667])

DM_30_sig_005_b_60_Ferm = np.array([2.09,1.24,0.5,0.0657])
DM_30_sig_005_b_60_Ferm_error = np.array([0.05404195901,0.04071404344,0.07909698688,0.03083050437])

#--------------------------------------------------
# Fermi + ASTROGAM
#--------------------------------------------------

# FA means Fermi + ASTROGAM

DM_30_sig_005_b_20_FA = np.array([7.01,4.22,1.71,0.23])   
DM_30_sig_005_b_20_FA_error = np.array([0.1000506538,0.07576828712,0.1547298721,0.0564071213])

DM_30_sig_005_b_40_FA = np.array([7.46,4.39,1.88,0.332])
DM_30_sig_005_b_40_FA_error = np.array([0.1024241183,0.07923719665,0.08854377448,0.03478505426])

DM_30_sig_005_b_60_FA = np.array([7.89,4.73,1.9,0.324])
DM_30_sig_005_b_60_FA_error = np.array([0.1069884729,0.0799674934,0.1662768775,0.06235382907])

#==================================================
#==================================================
# Eveything with σ = 0.10 
#==================================================
#==================================================

#--------------------------------------------------
# Fermi only
#--------------------------------------------------



DM_30_sig_010_b_20_Ferm = np.array([6.46,3.58,1.61,0.119])
DM_30_sig_010_b_20_Ferm_error = np.array([0.2967580384,0.2176610515,0.1397187651,0.04901703785])

DM_30_sig_010_b_40_Ferm = np.array([6.42,4.21,1.77,0.235])
DM_30_sig_010_b_40_Ferm_error = np.array([0.2956033378,0.2292080569,0.07526220831,0.02893484059])

DM_30_sig_010_b_60_Ferm = np.array([7.28,4.5,1.91,0.215])
DM_30_sig_010_b_60_Ferm_error = np.array([0.330244354,0.2349815596,0.1420281662,0.05559883092])


#--------------------------------------------------
# Fermi + ASTROGAM
#--------------------------------------------------


# FA means Fermi + ASTROGAM

DM_30_sig_010_b_20_FA = np.array([37.5,22.7,9.18,1.36])   
DM_30_sig_010_b_20_FA_error = np.array([0.7794228634,0.5663806141,0.3487195626,0.1275944095])

DM_30_sig_010_b_40_FA = np.array([43.4,26.2,10.5,1.58])
DM_30_sig_010_b_40_FA_error = np.array([0.7851963661,0.6235382907,0.2181971586,0.08127053587])

DM_30_sig_010_b_60_FA = np.array([43.9,27.4,11.7,1.73])
DM_30_sig_010_b_60_FA_error = np.array([0.8256108849,0.6062177826,0.4335900522,0.1478016689])



#==================================================
#==================================================
# Everything with σ = 0.25
#==================================================
#==================================================


#--------------------------------------------------
# Fermi only
#--------------------------------------------------

DM_30_sig_025_b_20_Ferm = np.array([89.4,50.9,19.1,2.5])
DM_30_sig_025_b_20_Ferm_error = np.array([1.143153533,0.7621023553,0.4751592715,0.1697409791])

DM_30_sig_025_b_40_Ferm = np.array([102.0,58.2,22.3,2.94])
DM_30_sig_025_b_40_Ferm_error = np.array([1.252850084,0.8544783984,0.3004163777,0.1030902517])

DM_30_sig_025_b_60_Ferm = np.array([109.0,62.8,24.7,3.35])
DM_30_sig_025_b_60_Ferm_error = np.array([1.206662063,0.993042463,0.5623391622,0.1934123402])


#--------------------------------------------------
# Fermi + ASTROGAM
#--------------------------------------------------

DM_30_sig_025_b_20_FA = np.array([318.0,181.0,70.4,9.94])
DM_30_sig_025_b_20_FA_error = np.array([2.292080569,1.58771324,0.9526279442,0.3313990545])

DM_30_sig_025_b_40_FA = np.array([362.0,207.0,79.5,11.5])
DM_30_sig_025_b_40_FA_error = np.array([2.482606158,1.726277305,0.5723722565,0.2083940978])

DM_30_sig_025_b_60_FA = np.array([387.0,223.0,87.1,12.1])
DM_30_sig_025_b_60_FA_error = np.array([2.505700168,2.026499445,1.096965511,0.3908661322])

# %% [markdown]
# ##### DM = 100 GeV

# %%
#===================================================
#===================================================
# First everything with σ = 0.05
#===================================================
#===================================================

#--------------------------------------------------
# Fermi only
#--------------------------------------------------

DM_100_sig_005_b_20_Ferm = np.array([3.65,2.25,0.796,0.177])
DM_100_sig_005_b_20_Ferm_error = np.array([0.07120393248,0.05513740412,0.1131606528,0.040760929])

DM_100_sig_005_b_40_Ferm = np.array([3.89,2.4,1.04,0.189])
DM_100_sig_005_b_40_Ferm_error = np.array([0.07302967433,0.05696314598,0.06482669203,0.02580418571])

DM_100_sig_005_b_60_Ferm = np.array([4.15,2.51,1.19,0.205])
DM_100_sig_005_b_60_Ferm_error = np.array([0.07631600968,0.05732829435,0.1166247544,0.04699631191])

#--------------------------------------------------
# Fermi + ASTROGAM
#--------------------------------------------------

# FA means Fermi + ASTROGAM

DM_100_sig_005_b_20_FA = np.array([7.44,4.64,1.76,0.381])   
DM_100_sig_005_b_20_FA_error = np.array([0.1040672859,0.08033264177,0.1593486743,0.06235382907])

DM_100_sig_005_b_40_FA = np.array([7.94,4.88,2.14,0.398])
DM_100_sig_005_b_40_FA_error = np.array([0.1064407503,0.08161066107,0.09360341874,0.03857978745])

DM_100_sig_005_b_60_FA = np.array([8.33,5.07,2.28,0.412])
DM_100_sig_005_b_60_FA_error = np.array([0.111005105,0.08361897711,0.1755144818,0.06812733176])

#==================================================
#==================================================
# Eveything with σ = 0.10 
#==================================================
#==================================================

#--------------------------------------------------
# Fermi only
#--------------------------------------------------



DM_100_sig_010_b_20_Ferm = np.array([20.4,12.3,5.0,0.692])
DM_100_sig_010_b_20_Ferm_error = np.array([0.5063361861,0.4116507419,0.255188819,0.09122134253])

DM_100_sig_010_b_40_Ferm = np.array([21.9,12.7,5.31,0.787])
DM_100_sig_010_b_40_Ferm_error = np.array([0.5513695071,0.3775870761,0.1476783667,0.05723722565])

DM_100_sig_010_b_60_Ferm = np.array([22.7,13.3,5.45,0.839])
DM_100_sig_010_b_60_Ferm_error = np.array([0.5946707773,0.4618802154,0.2817469314,0.1091192009])


#--------------------------------------------------
# Fermi + ASTROGAM
#--------------------------------------------------


# FA means Fermi + ASTROGAM

DM_100_sig_010_b_20_FA = np.array([44.4,27.4,11.0,1.56])   
DM_100_sig_010_b_20_FA_error = np.array([0.8660254038,0.6581793069,0.3671947712,0.1478016689])

DM_100_sig_010_b_40_FA = np.array([50.8,28.3,11.7,1.73])
DM_100_sig_010_b_40_FA_error = np.array([0.8660254038,0.6639528096,0.227051536,0.08506526906])

DM_100_sig_010_b_60_FA = np.array([51.2,30.7,12.4,1.94])
DM_100_sig_010_b_60_FA_error = np.array([0.9526279442,0.7274613392,0.4335900522,0.1605033748])



#==================================================
#==================================================
# Everything with σ = 0.25
#==================================================
#==================================================


#--------------------------------------------------
# Fermi only
#--------------------------------------------------

DM_100_sig_025_b_20_Ferm = np.array([209.0,123.0,47.4,6.82])
DM_100_sig_025_b_20_Ferm_error = np.array([1.928349899,1.316358614,0.7794228634,0.27886018])

DM_100_sig_025_b_40_Ferm = np.array([232.0,136.0,52.8,7.6])
DM_100_sig_025_b_40_Ferm_error = np.array([1.986084926,1.454922678,0.4806662043,0.1698143104])

DM_100_sig_025_b_60_Ferm = np.array([251.0,148.0,58.2,8.42])
DM_100_sig_025_b_60_Ferm_error = np.array([2.090007974,1.431828668,0.9295339334,0.3186973486])


#--------------------------------------------------
# Fermi + ASTROGAM
#--------------------------------------------------

DM_100_sig_025_b_20_FA = np.array([362.0,209.0,80.7,11.7])
DM_100_sig_025_b_20_FA_error = np.array([2.396003617,1.789785834,0.9988159657,0.3723909236])

DM_100_sig_025_b_40_FA = np.array([404.0,237.0,91.5,12.8])
DM_100_sig_025_b_40_FA_error = np.array([2.63849073,1.968764418,0.6261309767,0.2210432084])

DM_100_sig_025_b_60_FA = np.array([437.0,257.0,99.8,14.1])
DM_100_sig_025_b_60_FA_error = np.array([2.678905249,1.974537921,1.223982571,0.4283938997])

# %% [markdown]
# ## Plotting

# %%
plot_pretty()

fig, axes = plt.subplots(nrows=3, ncols=3, figsize = (15.0,15.0))

plt.rc('xtick',labelsize=17)
plt.rc('ytick',labelsize=17)

#===============================================================
#===============================================================
# Dark matter 10 GeV, σ= 0.05

#Fermi
axes[0,0].plot(DM_10_sig_005_b_20_Ferm, flux, c='g', linewidth=2.5, markersize=8,markerfacecolor='black',marker='o', label=r'\tiny{\tiny{.}}')
axes[0,0].plot(DM_10_sig_005_b_40_Ferm, flux, c='mediumseagreen',linewidth=2.5,markersize=8, markerfacecolor='black',marker='v',label=r'\tiny{.}')
axes[0,0].plot(DM_10_sig_005_b_60_Ferm, flux, c='mediumaquamarine',linewidth=2.5,markersize=8, markerfacecolor='black',marker='^',label=r'\tiny{.}')

#Fermi + Astrogram
axes[0,0].plot(DM_10_sig_005_b_20_FA, flux, c='r',linewidth=2.5,markersize=8, markerfacecolor='black',marker='o',label=r'$b$=-20$^o$')
axes[0,0].plot(DM_10_sig_005_b_40_FA, flux, c='tomato', linewidth=2.5,markersize=8, markerfacecolor='black',marker='v',label=r'$b$=-40$^o$')
axes[0,0].plot(DM_10_sig_005_b_60_FA, flux, c='lightsalmon',linewidth=2.5,markersize=8, markerfacecolor='black',marker='^',label=r'$b$=-60$^o$')


#Customize
#--------------

#text
axes[0,0].text(1.2 ,3.65e-9, r'Fermi LAT', fontsize=15)
axes[0,0].text(1.2 ,3.4e-9, r'only', fontsize=15)
axes[0,0].text(5.6 ,2.5e-9, r'Fermi LAT + ', fontsize=15)
axes[0,0].text(5.5 ,2.2E-9, r'e-ASTROGAM', fontsize=14)

#labels

axes[0,0].legend(frameon=False,ncol=2, loc='lower right', fontsize=15, columnspacing=0.1)

#titles 

axes[0,0].set_title('$\mathbf{\sigma_{68} = 0.05^o}$', fontsize = 20, y = 1.08)

axes[0,0].set_ylabel('Flux $> 1$ GeV', fontsize = 18)

axes[0,0].text(-3.15 ,2.9E-9, r'\textbf{$\mathbf{ m_\chi}$ = 10 GeV}', fontsize=18, rotation='vertical')

axes[0,0].set_xlim(-0.3,9.0)

#===============================================================
#===============================================================
# Dark matter 10 GeV,  σ = 0.10

#Fermi
axes[0,1].plot(DM_10_sig_010_b_20_Ferm, flux, c='g',  markersize=8,markerfacecolor='black',marker='o', linewidth=2.5)
axes[0,1].plot(DM_10_sig_010_b_40_Ferm, flux, c='mediumseagreen', markersize=8,markerfacecolor='black',marker='v', linewidth=2.5)
axes[0,1].plot(DM_10_sig_010_b_60_Ferm, flux, c='mediumaquamarine', markersize=8,markerfacecolor='black',marker='^', linewidth=2.5)

# Fermi+Astrogam

axes[0,1].plot(DM_10_sig_010_b_20_FA, flux, c='r', markersize=8,markerfacecolor='black',marker='o', linewidth=2.5)
axes[0,1].plot(DM_10_sig_010_b_40_FA, flux, c='tomato', markersize=8,markerfacecolor='black',marker='v', linewidth=2.5)
axes[0,1].plot(DM_10_sig_010_b_60_FA, flux, c='lightsalmon',  markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)


#======================================================
#customize 

#titles
axes[0,1].set_title('$\mathbf{\sigma_{68} = 0.10^o}$', fontsize = 20,y = 1.08)

axes[0,1].set_xlim(-2.0,53.0)



#===============================================================
#===============================================================
# Dark matter 10 GeV, σ = 0.25

# Fermi 
axes[0,2].plot(DM_10_sig_025_b_20_Ferm, flux, c='g', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[0,2].plot(DM_10_sig_025_b_40_Ferm, flux, c='mediumseagreen', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[0,2].plot(DM_10_sig_025_b_60_Ferm, flux, c='mediumaquamarine', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)

# Fermi+Astrogam

axes[0,2].plot(DM_10_sig_025_b_20_FA, flux, c='r', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[0,2].plot(DM_10_sig_025_b_40_FA, flux, c='tomato', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[0,2].plot(DM_10_sig_025_b_60_FA, flux, c='lightsalmon', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)

#customize

#title
axes[0,2].set_title('$\mathbf{\sigma_{\scriptsize{68}} = 0.25^o}$', fontsize = 20, y = 1.08)

axes[0,2].set_xlim(-20.0,500.0)

#==============================================================
#==============================================================
#  Dark matter 30 GeV, σ = 0.05

#Fermi
axes[1,0].plot(DM_30_sig_005_b_20_Ferm, flux, c='g', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[1,0].plot(DM_30_sig_005_b_40_Ferm, flux, c='mediumseagreen', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[1,0].plot(DM_30_sig_005_b_60_Ferm, flux, c='mediumaquamarine', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)


#Fermi + Astrogam

axes[1,0].plot(DM_30_sig_005_b_20_FA, flux, c='r', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[1,0].plot(DM_30_sig_005_b_40_FA, flux, c='tomato', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[1,0].plot(DM_30_sig_005_b_60_FA, flux, c='lightsalmon', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)

#customize

#titles
axes[1,0].set_ylabel('Flux $> 1$ GeV', fontsize = 18)

axes[1,0].text(-3.15 ,2.9E-9, r'\textbf{$\mathbf{ m_\chi}$ = 30 GeV}', fontsize=18, rotation='vertical')

axes[1,0].set_xlim(-0.3,9.0)

#==============================================================
#==============================================================
#  Dark matter 30 GeV, σ = 0.10

#Fermi
axes[1,1].plot(DM_30_sig_010_b_20_Ferm, flux, c='g', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[1,1].plot(DM_30_sig_010_b_40_Ferm, flux, c='mediumseagreen', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[1,1].plot(DM_30_sig_010_b_60_Ferm, flux, c='mediumaquamarine', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)

#Fermi + Astrogam

axes[1,1].plot(DM_30_sig_010_b_20_FA, flux, c='r', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[1,1].plot(DM_30_sig_010_b_40_FA, flux, c='tomato', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[1,1].plot(DM_30_sig_010_b_60_FA, flux, c='lightsalmon', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)

axes[1,1].set_xlim(-2.0,53.0)

#==============================================================
#==============================================================
#  Dark matter 30 GeV, σ = 0.25

#Fermi 
axes[1,2].plot(DM_30_sig_025_b_20_Ferm, flux, c='g', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[1,2].plot(DM_30_sig_025_b_40_Ferm, flux, c='mediumseagreen', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[1,2].plot(DM_30_sig_025_b_60_Ferm, flux, c='mediumaquamarine', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)

#Fermi+Astrogam
axes[1,2].plot(DM_30_sig_025_b_20_FA, flux, c='r', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[1,2].plot(DM_30_sig_025_b_40_FA, flux, c='tomato', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[1,2].plot(DM_30_sig_025_b_60_FA, flux, c='lightsalmon', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)


axes[1,2].set_xlim(-20.0,500.0)
#==============================================================
#==============================================================
#  Dark matter 100 GeV, σ = 0.05

#Fermi
axes[2,0].plot(DM_100_sig_005_b_20_Ferm, flux, c='g', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[2,0].plot(DM_100_sig_005_b_40_Ferm, flux, c='mediumseagreen', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[2,0].plot(DM_100_sig_005_b_60_Ferm, flux, c='mediumaquamarine', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)

#Fermi + Astrogam 

axes[2,0].plot(DM_100_sig_005_b_20_FA, flux, c='r', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[2,0].plot(DM_100_sig_005_b_40_FA, flux, c='tomato', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[2,0].plot(DM_100_sig_005_b_60_FA, flux, c='lightsalmon', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)


#customize

#titles
axes[2,0].set_ylabel('Flux $> 1$ GeV', fontsize = 18)

axes[2,0].set_xlabel('TS =$2\Delta \ln{(\cal{L})}$', fontsize = 16)

axes[2,0].text(-3.15 ,3.0E-9, r'\textbf{$\mathbf{ m_\chi}$ = 100 GeV}', fontsize=18, rotation='vertical')

axes[2,0].set_xlim(-0.3,9.0)
#==============================================================
#==============================================================
#  Dark matter 30 GeV, σ = 0.10

#Fermi 
axes[2,1].plot(DM_100_sig_010_b_20_Ferm, flux, c='g', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[2,1].plot(DM_100_sig_010_b_40_Ferm, flux, c='mediumseagreen', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[2,1].plot(DM_100_sig_010_b_60_Ferm, flux, c='mediumaquamarine', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)

#Fermi+Astrogam

axes[2,1].plot(DM_100_sig_010_b_20_FA, flux, c='r', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[2,1].plot(DM_100_sig_010_b_40_FA, flux, c='tomato', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[2,1].plot(DM_100_sig_010_b_60_FA, flux, c='lightsalmon', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)

#customize

#titles

axes[2,1].set_xlabel('TS =$2\Delta \ln{(\cal{L})}$', fontsize = 16)

axes[2,1].set_xlim(-2.0,53.0)

#==============================================================
#==============================================================
#  Dark matter 30 GeV, σ = 0.25

# Fermi
axes[2,2].plot(DM_100_sig_025_b_20_Ferm, flux, c='g', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[2,2].plot(DM_100_sig_025_b_40_Ferm, flux, c='mediumseagreen', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[2,2].plot(DM_100_sig_025_b_60_Ferm, flux, c='mediumaquamarine', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)

#Fermi+Astrogam

axes[2,2].plot(DM_100_sig_025_b_20_FA, flux, c='r', markersize=8,markerfacecolor='black',marker='o',linewidth=2.5)
axes[2,2].plot(DM_100_sig_025_b_40_FA, flux, c='tomato', markersize=8,markerfacecolor='black',marker='v',linewidth=2.5)
axes[2,2].plot(DM_100_sig_025_b_60_FA, flux, c='lightsalmon', markersize=8,markerfacecolor='black',marker='^',linewidth=2.5)

#customize

#titles

axes[2,2].set_xlabel('TS =$2\Delta \ln{(\cal{L})}$', fontsize = 16)
axes[2,2].set_xlim(-20.0,500.0)

#=============================================================
#=============================================================

plt.savefig('NFW_1PS.pdf')
plt.show()
